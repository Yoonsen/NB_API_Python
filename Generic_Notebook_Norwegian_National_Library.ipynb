# %% [markdown]
# #### Boot cell
#
# Skip if `module_update.py` is in same folder as notebook, next cell downloads this file which in turn will download other files.

# %%
# !curl "https://raw.githubusercontent.com/Yoonsen/Modules/master/module_update.py" > "module_update.py"

# %% [markdown]
# #### Get essentials
#
# Import text and graph modules for analysis, and css for display

# %%
from module_update import update, css
# Out:
# Updated file nbtext.py

# %%
from IPython.display import HTML
button_text = "Klikk her"
display(
        HTML(
        '''<div>
                <style>
                 .mybutton {
                    background-color: lightgrey;
                    border: none;
                    color: white;
                    padding: 10px 16px;
                    text-align: center;
                    text-decoration: none;
                    display: inline-block;
                    font-size: 16px;
                    margin: 4px 2px;
                    cursor: pointer;
                }
            </style>
            <script>
                code_show=true; 
                function code_toggle() {
                 if (code_show){
                 $('div.input').hide();
                 } else {
                 $('div.input').show();
                 }
                 code_show = !code_show
                } 
                $( document ).ready(code_toggle);
            </script>
            <form  action="javascript:code_toggle()">
                <input class='mybutton' type="submit" value=''' + '"'  + button_text + '"' + '''>
            </form>
        </div>'''
        ))
# Out:
# <div>
#                 <style>
#                  .mybutton {
#                     background-color: lightgrey;
#                     border: none;
#                     color: white;
#                     padding: 10px 16px;
#                     text-align: center;
#                     text-decoration: none;
#                     display: inline-block;
#                     font-size: 16px;
#                     margin: 4px 2px;
#                     cursor: pointer;
#                 }
#             </style>
#             <script>
#                 code_show=true;
#                 function code_toggle() {
#                  if (code_show){
#                  $('div.input').hide();
#                  } else {
#                  $('div.input').show();
#                  }
#                  code_show = !code_show
#                 }
#                 $( document ).ready(code_toggle);
#             </script>
#             <form  action="javascript:code_toggle()">
#                 <input class='mybutton' type="submit" value="Klikk her">
#             </form>
#         </div>

# %% [markdown]
# # Generisk analyse

# %% [markdown]
# Intro

# %% [markdown]
# ### Start med å importere modulene

# %%
update('graph_networkx_louvain')
import nbtext as nb
import graph_networkx_louvain as gnl
from graph_networkx_louvain import cutdown, make_collocation_graph
# Out:
# Updated file graph_networkx_louvain.py

# %% [markdown]
# ## Bygg korpus og analysér
#
# Hent URN-er fra tekst eller metadata

# %% [markdown]
# ### Fra Word .docx

# %%
korpus = nb.get_urns_from_docx()

# %% [markdown]
# ### Fra tekstfil .txt

# %%
korpus = nb.get_urns_from_text()

# %% [markdown]
# ### Fra metadata
#
# dewey, emneord, navn , år, etc. Her kan [Webdewey](http://deweysearchno.pansoft.de/webdeweysearch/index.html) være til god hjelp.

# %%
korpus = nb.get_urn({'ddk': '799.2%', 'year':1980, 'next':50, 'limit':300})
len(korpus)
# Out:
# 221

# %% [markdown]
# ## Analyse

# %%
nb.get_urnkonk('kvinner', {'urns':korpus})
# Out:
# <table><tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2009041504139?searchText=kvinner' target='_blank' style='text-decoration:none'>Morgenlandet, Schjelderup, Hans Hille, 2000</a>
#                 </td>
#                 <td>som med kaldt blod skyter</td>
#                 <td>kvinner</td>
#                 <td style='text-align:left'>og barn . Det er</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2009041504139?searchText=kvinner' target='_blank' style='text-decoration:none'>Morgenlandet, Schjelderup, Hans Hille, 2000</a>
#                 </td>
#                 <td>slår an på noen unge</td>
#                 <td>kvinner</td>
#                 <td style='text-align:left'>, som ikke vil ha</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2015062208214?searchText=kvinner' target='_blank' style='text-decoration:none'>Jegerfakta, , 2003</a>
#                 </td>
#                 <td>5 % av jegerne er</td>
#                 <td>kvinner</td>
#                 <td style='text-align:left'>, a □ nei ,</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2016070648093?searchText=kvinner' target='_blank' style='text-decoration:none'>Jakt på villrein, Skåtan, Jon Erling, 2001</a>
#                 </td>
#                 <td>var radikale føregangsmenn og -</td>
#                 <td>kvinner</td>
#                 <td style='text-align:left'>, og deres aktiviteter førte</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2014061606014?searchText=kvinner' target='_blank' style='text-decoration:none'>Jaktglede, Aker, Pierre, 2006</a>
#                 </td>
#                 <td>eller nær fluoriserende oransje -</td>
#                 <td>kvinner</td>
#                 <td style='text-align:left'>som menn - såkalt hunters</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2015030606043?searchText=kvinner' target='_blank' style='text-decoration:none'>Fra en rypejegers dagbok, Steen, Johan B., 1984</a>
#                 </td>
#                 <td>en mann kunne ha mange</td>
#                 <td>kvinner</td>
#                 <td style='text-align:left'>bare han først hadde mange</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2015030606043?searchText=kvinner' target='_blank' style='text-decoration:none'>Fra en rypejegers dagbok, Steen, Johan B., 1984</a>
#                 </td>
#                 <td>vanligere hos menn enn hos</td>
#                 <td>kvinner</td>
#                 <td style='text-align:left'>. Andre hevder at denne</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2015030606043?searchText=kvinner' target='_blank' style='text-decoration:none'>Fra en rypejegers dagbok, Steen, Johan B., 1984</a>
#                 </td>
#                 <td>Det står</td>
#                 <td>kvinner</td>
#                 <td style='text-align:left'>bakom alt. Også bak jakten</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2015030606043?searchText=kvinner' target='_blank' style='text-decoration:none'>Fra en rypejegers dagbok, Steen, Johan B., 1984</a>
#                 </td>
#                 <td>å skaffe vilt til sine</td>
#                 <td>kvinner</td>
#                 <td style='text-align:left'>. Den beste jeger ,</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2015030606043?searchText=kvinner' target='_blank' style='text-decoration:none'>Fra en rypejegers dagbok, Steen, Johan B., 1984</a>
#                 </td>
#                 <td>nødvendigheten frem dyktige jegere og</td>
#                 <td>kvinner</td>
#                 <td style='text-align:left'>som satte pris på dem</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2016070548066?searchText=kvinner' target='_blank' style='text-decoration:none'>Småviltjakt, Haug, Frank, 2002</a>
#                 </td>
#                 <td>hoteller blir fylt opp av</td>
#                 <td>kvinner</td>
#                 <td style='text-align:left'>og menn i alt fra</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2013021538110?searchText=kvinner' target='_blank' style='text-decoration:none'>ABC for jegerprøven, , 2004</a>
#                 </td>
#                 <td>jegerprøven , derav 21 %</td>
#                 <td>kvinner</td>
#                 <td style='text-align:left'>. Av de vel 192</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2014070848029?searchText=kvinner' target='_blank' style='text-decoration:none'>Enkel rypejakt, Pettersen, Marius Nergård, 2008</a>
#                 </td>
#                 <td>av jegerne er i dag</td>
#                 <td>kvinner</td>
#                 <td style='text-align:left'>.</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2014070848029?searchText=kvinner' target='_blank' style='text-decoration:none'>Enkel rypejakt, Pettersen, Marius Nergård, 2008</a>
#                 </td>
#                 <td>Generelt kan vi si at</td>
#                 <td>kvinner</td>
#                 <td style='text-align:left'>bør ha i seg minst</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2013100305123?searchText=kvinner' target='_blank' style='text-decoration:none'>Fra trost til grizzly, Sveinunggard, Gunnar, 1988</a>
#                 </td>
#                 <td>Det var endog</td>
#                 <td>kvinner</td>
#                 <td style='text-align:left'>som påtok seg å kurere</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2013100305123?searchText=kvinner' target='_blank' style='text-decoration:none'>Fra trost til grizzly, Sveinunggard, Gunnar, 1988</a>
#                 </td>
#                 <td>folk ; ja , seiv</td>
#                 <td>kvinner</td>
#                 <td style='text-align:left'>i menstruasjonsperioden hevdes å være</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2008080804038?searchText=kvinner' target='_blank' style='text-decoration:none'>store bjørneskjelven, Parling, Nils, 1998</a>
#                 </td>
#                 <td>lite , lite håp som</td>
#                 <td>kvinner</td>
#                 <td style='text-align:left'>gjerne har - i det</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2008080804038?searchText=kvinner' target='_blank' style='text-decoration:none'>store bjørneskjelven, Parling, Nils, 1998</a>
#                 </td>
#                 <td>etter gull , pelsverk ,</td>
#                 <td>kvinner</td>
#                 <td style='text-align:left'>, alt ! Tlingits var</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2008080804038?searchText=kvinner' target='_blank' style='text-decoration:none'>store bjørneskjelven, Parling, Nils, 1998</a>
#                 </td>
#                 <td>fiskere , villmarksboere . Flittige</td>
#                 <td>kvinner</td>
#                 <td style='text-align:left'>og unger som tidlig ble</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www
